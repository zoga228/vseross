# %% [markdown]
# batch gr dec:
# обновление весов после всего датасета

# %% [markdown]
# Stochastic Gradient Descent: обновление градиента на каждом примере

# %% [markdown]
# Mini-Batch Gradient Descent: градиент между батчами

# %% [markdown]
# Метод	Скорость	Точность	Использование
# Batch GD	🐢 Медленный	✅ Высокая	Маленькие датасеты
# SGD	🚀 Очень быстрый	❌ Шумный	Онлайн-обучение, большие данные
# Mini-Batch GD	⚡ Средний	✅ Оптимальный	Нейросети, большие датасеты
