# %%
import nltk
nltk.download('punkt')  # загрузка необходимых пакетов
from nltk.tokenize import word_tokenize

text = "Машинное, обучение — это так интересно!"
tokens = word_tokenize(text.lower())
print(tokens)
# Результат: ['машинное', 'обучение', '—', 'это', 'интересно', '!']
# Out:
# ['машинное', ',', 'обучение', '—', 'это', 'так', 'интересно', '!']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\zhnbk\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords

stop_words = set(stopwords.words('russian'))
filtered_tokens = [word for word in tokens if word not in stop_words]
print(filtered_tokens)
# Результат: список слов без часто встречающихся (например, "это")
# Out:
# ['машинное', ',', 'обучение', '—', 'это', 'интересно', '!']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\zhnbk\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
