# %%
# !pip install wandb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/20.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/20.2 MB ? eta -:--:--
#     --------------------------------------- 0.3/20.2 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/20.2 MB 3.0 MB/s eta 0:00:07
#    --- ------------------------------------ 1.6/20.2 MB 3.2 MB/s eta 0:00:06
#    ---- ----------------------------------- 2.4/20.2 MB 3.0 MB/s eta 0:00:06
#    ----- ---------------------------------- 2.9/20.2 MB 3.0 MB/s eta 0:00:06
#    ------- -------------------------------- 3.7/20.2 MB 3.1 MB/s eta 0:00:06
#    -------- ------------------------------- 4.5/20.2 MB 3.2 MB/s eta 0:00:05
#    ---------- ----------------------------- 5.2/20.2 MB 3.3 MB/s eta 0:00:05
#    ----------- ---------------------------- 5.8/20.2 MB 3.3 MB/s eta 0:00:05
# ...

# %%
# !wandb login
# Out:
# 'wandb' is not recognized as an internal or external command,
# operable program or batch file.
